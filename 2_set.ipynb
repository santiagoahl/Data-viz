# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagoahl/Data-viz/blob/main/2_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What is `set`?
#
# `set` is used to costumize our graphs, the basic syntaxis is:
#
# `sns.set(style, palette, font, font_scale,kwargs...)`

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x=['A','B','C'], y=[1,3,2])
plt.show()

# %%
sns.set(style='darkgrid', palette='deep')
sns.barplot(x=['A','B','C'], y=[1,3,2])
plt.show()

# %%
sns.set(style='darkgrid', palette='dark')
sns.barplot(x=['A','B','C'], y=[1,3,2])
plt.show()

# %%
sns.set(style='darkgrid', palette='deep', font="Verdana", font_scale=1)
sns.barplot(x=['A','B','C'], y=[1,3,2])
plt.show()
